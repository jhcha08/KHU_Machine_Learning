# %% [markdown]
# # 옵티마이저 변화

# %%
import matplotlib.pyplot as plt
import numpy as np

# Xception_bs64_lr0.001

train = [0.59261, 0.58182, 0.83862, 0.83932]
test = [0.69407, 0.58562, 0.72636, 0.73293]

label = ['SGD','AdaGrad','RMSProp', 'Adam']

plt.figure()

x = np.arange(len(label))

plt.bar(x-0.1, train, label='Train', width = 0.2)
plt.bar(x+0.1, test, label='Test', width = 0.2)
plt.xticks(x, label)
plt.ylim(0,1.17)

plt.legend()
plt.xlabel('Optimizer')
plt.ylabel('Accuracy')
plt.title('Train and Test Accuracy with Changing Optimizer')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

SAVEPATH = 'xception_opt\\'

text_acc1 = pd.read_csv(SAVEPATH+'Xception_bs64_lr0.001_Adagrad.acc.csv')
text_acc2 = pd.read_csv(SAVEPATH+'xception_acc_train_adam_64_0.001.csv')
text_acc3 = pd.read_csv(SAVEPATH+'Xception_bs64_lr0.001_RMSprop_acc.csv')
text_acc4 = pd.read_csv(SAVEPATH+'Xception_bs64_lr0.001_SGD_acc.csv')

text_loss1 = pd.read_csv(SAVEPATH+'Xception_bs64_lr0.001_Adagrad_loss.csv')
text_loss2 = pd.read_csv(SAVEPATH+'xception_loss_train_adam_64_0.001.csv')
text_loss3 = pd.read_csv(SAVEPATH+'Xception_bs64_lr0.001_RMSprop_loss.csv')
text_loss4 = pd.read_csv(SAVEPATH+'Xception_bs64_lr0.001_SGD_loss.csv')

epochs = list(text_acc1['Epoch'])

# 하이퍼 파라미터에 따른 Train Acc 변화 그래프

acc1 = list(text_acc1['Train Acc'])
acc2 = list(text_acc2['Train Acc'])
acc3 = list(text_acc3['Train Acc'])
acc4 = list(text_acc4['Train Acc'])

plt.plot(epochs, acc1,label='AdaGrad', color='springgreen')
plt.plot(epochs, acc2,label='Adam', color='violet')
plt.plot(epochs, acc3,label='RMSProp', color='dodgerblue')
plt.plot(epochs, acc4,label='SGD', color='chocolate')

plt.title('Train Accuracy with Changing Optmizer')
plt.legend()
plt.show()

# 하이퍼 파라미터에 따른 Train Loss 변화 그래프

loss1 = list(text_loss1['Train Loss'])
loss2 = list(text_loss2['Train Loss'])
loss3 = list(text_loss3['Train Loss'])
loss4 = list(text_loss4['Train Loss'])

plt.plot(epochs, loss1,label='AdaGrad', color='springgreen')
plt.plot(epochs, loss2,label='Adam', color='violet')
plt.plot(epochs, loss3,label='RMSProp', color='dodgerblue')
plt.plot(epochs, loss4,label='SGD', color='chocolate')

plt.title('Train Loss with Changing Optmizer')
plt.legend()

plt.show()

# %% [markdown]
# # lr 변화

# %%
import matplotlib.pyplot as plt
import numpy as np

# Xception_Adam_bs64

train = [0.68959, 0.81837, 0.83932, 0.85769]
test = [0.69322, 0.74763, 0.73293, 0.73293]

label = ['0.1','0.01','0.001','0.0001']

plt.figure()

x = np.arange(len(label))

plt.bar(x-0.1, train, label='Train', width = 0.2)
plt.bar(x+0.1, test, label='Test', width = 0.2)
plt.xticks(x, label)
plt.ylim(0,1.17)

plt.legend()
plt.xlabel('Learning Rate')
plt.ylabel('Accuracy')
plt.title('Train and Test Accuracy with Changing Learning Rate')
plt.show()

plt.savefig('Xception_lr.jpg')

# %%
import pandas as pd
import matplotlib.pyplot as plt

SAVEPATH = 'xception_lr\\'

text_acc1 = pd.read_csv(SAVEPATH+'xception_acc_train_adam_64_0.0001.csv')
text_acc2 = pd.read_csv(SAVEPATH+'xception_acc_train_adam_64_0.001.csv')
text_acc3 = pd.read_csv(SAVEPATH+'xception_acc_train_adam_64_0.01.csv')
text_acc4 = pd.read_csv(SAVEPATH+'xception_acc_train_adam_64_0.1.csv')

text_loss1 = pd.read_csv(SAVEPATH+'xception_loss_train_adam_64_0.0001.csv')
text_loss2 = pd.read_csv(SAVEPATH+'xception_loss_train_adam_64_0.001.csv')
text_loss3 = pd.read_csv(SAVEPATH+'xception_loss_train_adam_64_0.01.csv')
text_loss4 = pd.read_csv(SAVEPATH+'xception_loss_train_adam_64_0.1.csv')

epochs = list(text_acc1['Epoch'])

# 하이퍼 파라미터에 따른 Train Acc 변화 그래프

acc1 = list(text_acc1['Train Acc'])
acc2 = list(text_acc2['Train Acc'])
acc3 = list(text_acc3['Train Acc'])
acc4 = list(text_acc4['Train Acc'])

plt.plot(epochs, acc1,label='0.0001', color='springgreen')
plt.plot(epochs, acc2,label='0.001', color='violet')
plt.plot(epochs, acc3,label='0.01', color='dodgerblue')
plt.plot(epochs, acc4,label='0.1', color='chocolate')

plt.title('Train Accuracy with Changing Learning rate')
plt.legend()
plt.show()

# 하이퍼 파라미터에 따른 Train Loss 변화 그래프

loss1 = list(text_loss1['Train Loss'])
loss2 = list(text_loss2['Train Loss'])
loss3 = list(text_loss3['Train Loss'])
loss4 = list(text_loss4['Train Loss'])

plt.plot(epochs, loss1,label='0.0001', color='springgreen')
plt.plot(epochs, loss2,label='0.001', color='violet')
plt.plot(epochs, loss3,label='0.01', color='dodgerblue')
plt.plot(epochs, loss4,label='0.1', color='chocolate')

plt.title('Train Loss with Changing Learning rate')
plt.legend()

plt.show()

# %% [markdown]
# # 배치 변화

# %%
import matplotlib.pyplot as plt
import numpy as np

# Xception_Adam_lr0.001

train = [0.81999, 0.83932, 0.87456, 0.90475]
test = [0.74215, 0.73293, 0.72882, 0.70712]

label = ['32','64','128','256']

plt.figure()

x = np.arange(len(label))

plt.bar(x-0.1, train, label='Train', width = 0.2)
plt.bar(x+0.1, test, label='Test', width = 0.2)
plt.xticks(x, label)
plt.ylim(0,1.17)

plt.legend()
plt.xlabel('Batch Size')
plt.ylabel('Accuracy')
plt.title('Train and Test Accuracy with Changing Batch Size')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

SAVEPATH = 'xception_bs\\'

text_acc1 = pd.read_csv(SAVEPATH+'xception_acc_train_adam_32_0.001.csv')
text_acc2 = pd.read_csv(SAVEPATH+'xception_acc_train_adam_64_0.001.csv')
text_acc3 = pd.read_csv(SAVEPATH+'xception_acc_train_adam_128_0.001.csv')
text_acc4 = pd.read_csv(SAVEPATH+'xception_acc_train_adam_256_0.001.csv')

text_loss1 = pd.read_csv(SAVEPATH+'xception_loss_train_adam_32_0.001.csv')
text_loss2 = pd.read_csv(SAVEPATH+'xception_loss_train_adam_64_0.001.csv')
text_loss3 = pd.read_csv(SAVEPATH+'xception_loss_train_adam_128_0.001.csv')
text_loss4 = pd.read_csv(SAVEPATH+'xception_loss_train_adam_256_0.001.csv')

epochs = list(text_acc1['Epoch'])

# 하이퍼 파라미터에 따른 Train Acc 변화 그래프

acc1 = list(text_acc1['Train Acc'])
acc2 = list(text_acc2['Train Acc'])
acc3 = list(text_acc3['Train Acc'])
acc4 = list(text_acc4['Train Acc'])

plt.plot(epochs, acc1,label='bs 32', color='springgreen')
plt.plot(epochs, acc2,label='bs 64', color='violet')
plt.plot(epochs, acc3,label='bs 128', color='dodgerblue')
plt.plot(epochs, acc4,label='bs 256', color='chocolate')

plt.title('Train Accuracy with Changing Batch Size')
plt.legend()
plt.show()

# 하이퍼 파라미터에 따른 Train Loss 변화 그래프

loss1 = list(text_loss1['Train Loss'])
loss2 = list(text_loss2['Train Loss'])
loss3 = list(text_loss3['Train Loss'])
loss4 = list(text_loss4['Train Loss'])

plt.plot(epochs, loss1,label='bs 32', color='springgreen')
plt.plot(epochs, loss2,label='bs 64', color='violet')
plt.plot(epochs, loss3,label='bs 128', color='dodgerblue')
plt.plot(epochs, loss4,label='bs 256', color='chocolate')

plt.title('Train Loss with Changing Batch Size')
plt.legend()

plt.show()
